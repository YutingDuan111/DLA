# %%
import plot_ani

# %%
# %load_ext autoreload
# %autoreload 2

# %%
animator = plot_ani.DLAAnimator(filename="dla-3-2.p")
# Out:
# Loaded perimeter history from dla-3-2.p

# %%
animator.create_animation()
# Out:
# Creating DLA gif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 animator.create_animation()
#
# File ~/Documents/GitHub/DLA/plot_ani.py:97, in DLAAnimator.create_animation(self, gif_name)
#      88 anim = animation.FuncAnimation(
#      89     self.fig,
#      90     self.animate,
#    (...)
#      94     repeat=True
#      95 )
#      96 print("Creating DLA gif")
# ---> 97 anim.save(gif_name,
#      98           writer='pillow',
#      99           fps=65,
#     100           dpi=300,
#     101           savefig_kwargs={
#     102               'pad_inches': 0.1,
#     103               'facecolor': 'black'
#     104           })
#     105 print(f"The GIF is saved as '{gif_name}'")
#     106 plt.tight_layout()
#
# ...

# %%
animator.create_final_image()
# Out:
# Creating PNG for the final image
# Final frame saved as DLA_Final.png
