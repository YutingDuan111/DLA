# %%
import matplotlib.pyplot as plt
import ETA

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
per = ETA.Perimeter(N = 200)
per.initialize_perimeter("random_walk")
per.get_grid()

# %%
while per.attached_particles < 200:
    per.simulate_one_particle(1,3)
per.save_grid("perimeter.pkl")

# %%
per.get_number_of_particles()
# Out:
# Attached: 200, Lost: 150

# %%
per.get_grid()

# %%
per.load_grid()
print(len(per.perimeter_history))
# Out:
# 350

# %%
time = 100
plt.figure(figsize=(6, 6))
plt.imshow(per.perimeter_history[time], cmap='gray')
plt.title(f"Perimeter at time {time}")
plt.axis('off')
plt.show()
