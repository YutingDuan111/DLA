# %%
import ETA

# %%
# %load_ext autoreload
# %autoreload 2

# %%
per = ETA.Perimeter()
per.initialize_perimeter("random_walk")
per.get_grid()

# %%
while per.attached_particles < 300:
    per.simulate_one_particle(1,1)
per.save_pickle("perimeter.pkl")

# %%
per.get_number_of_particles()
# Out:
# Launched: 1189, Attached: 300, Lost: 889

# %%
per.get_grid()

# %%
per.load_grid()
print(len(per.perimeter_history))
# Out:
# Loaded perimeter from timestamp 1189
# 300

# %%
per.load_grid("perimeter.pkl")
per.get_grid()
# Out:
# Loaded perimeter from timestamp 1189
