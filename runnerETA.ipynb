# %%
import ETA

# %%
# %load_ext autoreload
# %autoreload 2

# %%
per = ETA.Perimeter()
per.initialize_perimeter("random_walk")
per.get_grid()

# %%
while per.attached_particles < 60:
    per.simulate_one_particle(2,3)
per.save_grid("perimeter.pkl")

# %%
per.get_number_of_particles()
# Out:
# Launched: 3814, Attached: 60, Lost: 3754

# %%
per.get_grid()

# %%
per.load_grid()
print(len(per.perimeter_history))
# Out:
# Loaded perimeter from timestamp 3814
# 60

# %%
per.load_grid("perimeter.pkl")
per.get_grid()
# Out:
# Loaded perimeter from timestamp 28304
